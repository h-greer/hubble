# %%
import sys
sys.path.insert(0, '..')

# %%
# Basic imports
import jax.numpy as np
import jax.random as jr
import jax.scipy as jsp

from astropy.io import fits

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['image.cmap'] = 'inferno'
plt.rcParams["font.family"] = "serif"
plt.rcParams["image.origin"] = 'lower'
plt.rcParams['figure.dpi'] = 72
plt.rcParams["font.size"] = 24

# %%
data = '../data/n8qn21020_jif.fits'

with fits.open(data) as hdul:
    print(hdul.info())
# Out:
# Filename: ../data/n8qn21020_jif.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      78   ()
#   1  jit           1 ImageHDU        86   (64, 64)   int32
#   2  jit           2 ImageHDU        86   (64, 64)   int32
#   3  jit           3 ImageHDU        86   (64, 64)   int32
# None

# %%
# data = '../data/n8qn21020_jit.fits'

# with fits.open(data) as hdul:
#     print(hdul.info())

# %%
hdr = fits.getheader(data,ext=1)
print(hdr['XPIXINC'], hdr['YPIXINC'])
# Out:
# 2.0 2.0

# %%
hdr
# Out:
# XTENSION= 'IMAGE   '           / extension type
# BITPIX  =                   32 / bits per data value
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                   64 / length of first data axis
# NAXIS2  =                   64 / length of second data axis
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'jit     '           / extension name
# EXTVER  =                    1 / extension version number
# ROOTNAME= 'n8qn21020'          / rootname of the observation set
# EXPNAME = 'n8qn21t6j                ' / exposure identifier
# DATAMIN =                  0.0 / the minimum value of the data
# DATAMAX =                 63.0 / the maximum value of the data
# ASN_MTYP= 'EXP-TARG'           / Role of the Member in the Association
#
#               / World Coordinate System and Related Parameters
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.imshow(fits.getdata(data, ext=1), extent=(-64, 64, -64, 64))
plt.xlabel("X error (mas)")
plt.ylabel("Y error (mas)")
plt.gca().add_patch(plt.Circle((0,0), 7.,  color='r', fill=False))
# plt.gca().add_patch(plt.Rectangle((-43/2,-43/2), 43, 43, color='b', fill=False))
