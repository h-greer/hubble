# %%
import sys
sys.path.insert(0, '..')

# %%
# Basic imports
import jax.numpy as np
import jax.random as jr
import jax.scipy as jsp

from astropy.io import fits

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['image.cmap'] = 'inferno'
plt.rcParams["font.family"] = "serif"
plt.rcParams["image.origin"] = 'lower'
plt.rcParams['figure.dpi'] = 72
plt.rcParams["font.size"] = 24

# %%
data = '../data/MAST_2024-11-13T10_11_39.226Z/HST/n43ca5010_jif.fits'

with fits.open(data) as hdul:
    print(hdul.info())
# Out:
# Filename: ../data/MAST_2024-11-13T10_11_39.226Z/HST/n43ca5010_jif.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     105   ()
#   1  jit           1 ImageHDU        90   (64, 64)   int32
#   2  jit           2 ImageHDU        90   (64, 64)   int32
#   3  jit           3 ImageHDU        90   (64, 64)   int32
#   4  jit           4 ImageHDU        90   (64, 64)   int32
# None

# %%
hdr = fits.getheader(data,ext=1)
print(hdr['XPIXINC'], hdr['YPIXINC'])
# Out:
# 2.0 2.0

# %%
plt.figure(figsize=(10,10))
plt.imshow(fits.getdata(data, ext=1), extent=(-128, 128, -128, 128))
plt.xlabel("X error (mas)")
plt.ylabel("Y error (mas)")
plt.gca().add_patch(plt.Rectangle((-43/2,-43/2), 43, 43, color='b', fill=False))
